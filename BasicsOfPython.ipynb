# %% [markdown]
# #This is my first JUpyter Notebook.
# comments-
# 1. welcome to my youtube channel
# 2. My name is Piyush
# 3. Mujhe bhuk lgi hai

# %%
1 + 2
# Out:
# 3

# %%
3*3+3
# Out:
# 12

# %%
a=10
a+10
# Out:
# 20

# %%
a+ 100
# Out:
# 110

# %%
print(10)
# Out:
# 10

# %%
print(a*1000)
# Out:
# 10000

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
print(a/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(a/0)
#
# ZeroDivisionError: division by zero

# %%
a+5
# Out:
# 15

# %%
print(a+5)
# Out:
# 15

# %%
print("Welcome to my channel")
print("Hello World")
# Out:
# Welcome to my channel
# Hello World

# %%
#Single line and multi comments
'''
for single line, only hash
and for multiline comments- 3 dots upr 3 dots neeche
'''
print("Hello World")
# Out:
# Hello World

# %%
#Variable Declaration
#type is in-built function which shows type of variable
a = 10
type(a)
# Out:
# int

# %%
a
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %%
tenth = 10
b=10
c="Piyush"

# %%
type(c)
# Out:
# str

# %%
#Varible ka naam number se start nai ho skta
1a=10
# Out:
#   Cell In[15], line 2
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
#baad me number likh skte h variable k naam me
a1=10
a
# Out:
# 10

# %%
first_name="Piyushhh Yadaaaaavvvvvvv"
print(first_name)
# Out:
# Piyushhh Yadaaaaavvvvvvv

# %%
#you can name the variable as the name of data type
int = 1
print(int)
# Out:
# 1

# %%
def get_greeting(email= 5, name="there"):
    print("Hello", name, "welcome! You've registered your email:", email)

get_greeting(3393932032)
# Out:
# Hello there welcome! You've registered your email: 3393932032

# %%
##type function se varible ki type jaan skte hai
#integers
a = 10
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
#flaoting
a=100.5
type(a)
# Out:
# float

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
#Typecasting- Conversion of one datatype to another
int(a)
# Out:
# 100

# %%
a=10
float(a)
# Out:
# 10.0

# %%
#string datatype
str(a)
# Out:
# '10'

# %%
ch='A'
int(ch)
#ASCII value k liye wrong method
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 ch='A'
# ----> 2 int(ch)
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
#ord function- function converts characters to number
ch = 'a'
ord(ch)
# Out:
# 97

# %%
#chr function- converts number into character
a=90
chr(a)

#ascii value ranges from 0 to 127, so outside this range, so python switches to "Unicode representation"
# Out:
# 'Z'

# %%
#boolean
a= True
b= False
#we can also perform here the logical operations of boolean algebra
print(a&b)
# Out:
# False

# %%
#strings
name1 = "Piyush Yadav"

print(name1)
print(type(name1))
# Out:
# Piyush Yadav
# <class 'str'>

# %%
#concatenation in strings
"Good morning " + name1
# Out:
# 'Good morning Piyush Yadav'

# %%
name1 + 1

#yha concatenation nai hoga kyuki datatype alg h
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 name1 + 1
#       3 #yha concatenation nai hoga kyuki datatype alg h
#
# TypeError: can only concatenate str (not "int") to str

# %%
#strong typing - agar forcefully 2 diff datatypes ki concatenation krani h to, dono ko same type mein lao.
name1 + " " + str(1)
# Out:
# 'Piyush Yadav 1'

# %%
#Complex Numbers
j=1.0-2.3j   #left j mean- variable name, right j mean- under root -1
j
# Out:
# (1-2.3j)

# %%
print(j.real, j.imag)
# Out:
# 1.0 -2.3

# %%
#Dynamic Typing
"""
Dynamic typing means:

You don’t declare the data type explicitly
Python decides the type at runtime (while executing)
"""
a=10
a="Piyush"
a
# Out:
# 'Piyush'

# %%
#Strong Typing
"""
Strong typing means:

Python does NOT automatically convert (coerce) types in unsafe situations
You must explicitly convert types yourself
"""
a+ " Bhuk lgi hai"
# Out:
# 'Piyush Bhuk lgi hai'

# %%
a+ " 02020"
# Out:
# 'Piyush 02020'

# %%
#String Formatting
a=100
print("The value is:",a)
# Out:
# The value is: 100

# %%
first_name="Piyush"
last_name="Yadav"
print("The first name is {} and last name is {}".format(first_name,last_name))
# Out:
# The first name is Piyush and last name is Yadav

# %%
print(f"the first name is {first_name} and last name is {last_name}")
# Out:
# the first name is Piyush and last name is Yadav

# %%
#input type
a = input("Enter the number A: ")
b = input("Enter the number B: ")
print(a+b)
#iska output concatenate hojayega, because a and b string values hai.
# Out:
# Enter the number A:  12
# Enter the number B:  23
# 1223

# %%
#agar sach me add krna h to, without concatenation
print(int(a)+int(b))
# Out:
# 35
