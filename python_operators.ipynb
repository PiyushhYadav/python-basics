# %% [markdown]
# <h1 style = "font-size=10px; font-weight=bold;>
# Tutorial 4- Python Operators
# </h1>

# %% [markdown]
# <h1 style="color:black;">Tutorial 4: Python Operators</h1>
# 1) Logical
# 2) Equality
# 3) Comparison
# 4) Arithmetic

# %% [markdown]
# 4.1.1 Logical Operators
# In python, following keywords are used for boolean operations-
# 1) not: unary negation
# 2) and: conditional AND
# 3) or: conditional OR
# ### EXAMPLES

# %%
type(True)
# Out:
# bool

# %%
bool(1) #typecasting
# Out:
# True

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
age = int(input("Enter the Age:"))
if age>18 and age <= 35:
    print("Mid age")
# Out:
# Enter the Age: 34
# Mid age

# %% [markdown]
# ### Equality Operator
# following operations are present in python for equality check operation-
# 1) is: a is b returns true if variable/identifiers a and b points to the same object.
# 2) is not: a  is not  b returs true if variable/identifiers a and b points to the different object.
# 3) == : a == b returns true if variable/identifiers a and b have the same value.
# 4) != : a!=b returns true if variables/identifiers a and b has different value.

# %%
a = "Piyush"
b = "Sumit"
a == b
# Out:
# False

# %%
a = "Piyush"
b = "Sumit"
print(id(a))
print(id(b))
# Out:
# 2352899826016
# 2352899756784

# %%
a = "Piyush"
b = "Piyush"
print(id(a))
print(id(b))
##this means here the variable a and b are pointing to the same memory location since their Id's are same.
# Out:
# 1641996083408
# 1641996083408

# %%
a is b
# Out:
# True

# %% [markdown]
# ##### The main difference between 'is' and '==' is that 'is' checks whether the variable are pointing to the same memory or not. and '==' operator checks whether their value is equal or not.
# 👉 == checks value equality
# 👉 is checks object identity (same memory location)
# Example
# a = [1, 2, 3]
# b = [1, 2, 3]
#
# print(a == b)  # True (values same)
# print(a is b)  # False (different objects)
#
# 👉 Even though values are same, memory is different
#
# Example where both are True
# a = [1, 2, 3]
# b = a
#
# print(a == b)  # True
# print(a is b)  # True
#
# 👉 Both variables point to same object

# %%
lst=[1,2,3]
lst1=[1,2,3]
print(id(lst))
print(id(lst1))
##Yha ye dono dusre dusre objects ko point kr rhe h even though, the value is same.
# Out:
# 1403951159040
# 1403951158656

# %%
lst==lst1
# Out:
# True

# %%
lst is not lst1
# Out:
# True

# %% [markdown]
# ## Comparison Operators
#
# 1. `<` : less than
# 2. `>` : greater than
# 3. `<=` : less than or equal to
# 4. `>=` : greater than or equal to

# %%
marks = float(input("Enter your marks: "))
if marks >= 35:
    print("Pass")
    if marks>=50 and marks<=70:
        print("First Class")
elif marks<35:
    print("Fail")
# Out:
# Enter your marks:  67
# Pass
# First Class

# %% [markdown]
# ## Arithmetic Operators
#
# - `+` : addition
# - `-` : subtraction
# - `*` : multiplication
# - `/` : true division
# - `//` : integer division or floor division
# - `%` : modulo operator

# %%
48/4 #True division, gives value in float
# Out:
# 12.0

# %%
48//4 #floor or integer division, gives value in integer
# Out:
# 12

# %%
48%5 ## modulo gives remainder
# Out:
# 3
